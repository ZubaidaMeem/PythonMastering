# %%
import numpy as np

print (" --- Problem 1 Verification ---")
A = np . array ([[0 , -1] ,[1 , 0]])
B = np . array ([[2 , 0] , [0 , 1]])

# TODO : Compute AB and BA using the ’@’ operator
AB = None
BA = None

print ( f"AB :\n{AB}")
print ( f"BA :\n{BA}")
print ( f" Are they equal ? {np. array_equal (AB , BA)}\n")

print (" --- Problem 2 Verification ---")
C = np . array ([[1 , 2] , [2 , 4]])

# TODO : Calculate the determinant using np. linalg .det
det_C = None
print ( f" Determinant of C: { det_C }")

try:
    C_inv = np . linalg . inv ( C )
    print (" Matrix is invertible .")
except np . linalg . LinAlgError :
    print (" Matrix is singular (Not invertible ) - Space has collapsed !\n")

print (" --- Problem 3 Verification ---")
# Build the coefficient matrix and the output vector
coeff_matrix = np . array ([[3 , 2] , [1 , -1]])
b_vector = np . array ([7 , -1])

# TODO : Solve for the weights using np. linalg . solve
w = None
print ( f" Solved weights (w1 , w2): {w}")
